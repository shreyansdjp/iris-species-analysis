# %%
import pandas as pd

# %%
import sys
print("64-bit" if sys.maxsize > 2**32 else "32-bit")
print(sys.executable)
# Out:
# 64-bit
# /Users/pygo/work/personal/courses/cba-gh/iris-species-analysis/.venv/bin/python

# %%
df = pd.read_csv("./iris/processed.csv")
df.rename(columns={"Species": "species"}, inplace=True)
df
# Out:
#       id  sepal_length  sepal_width  petal_length  petal_width  species
# 0      1           5.1          3.5           1.4          0.2        0
# 1      2           4.9          3.0           1.4          0.2        0
# 2      3           4.7          3.2           1.3          0.2        0
# 3      4           4.6          3.1           1.5          0.2        0
# 4      5           5.0          3.6           1.4          0.2        0
# ..   ...           ...          ...           ...          ...      ...
# 145  146           6.7          3.0           5.2          2.3        2
# 146  147           6.3          2.5           5.0          1.9        2
# 147  148           6.5          3.0           5.2          2.0        2
# 148  149           6.2          3.4           5.4          2.3        2
# 149  150           5.9          3.0           5.1          1.8        2
#
# [150 rows x 6 columns]

# %%
from xgboost import XGBClassifier
from sklearn.model_selection import train_test_split
from sklearn.metrics import classification_report

# %%
x = df.loc[:, df.columns != 'species']
y = df['species']
x_train, x_test, y_train, y_test = train_test_split(x, y, stratify=y, random_state=2390)

# %%
xgb = XGBClassifier(
    n_estimators=500,
    learning_rate=0.05,
    max_depth=6,
    subsample=0.8,
    colsample_bytree=0.8,
    colsample_bylevel=1.0,
    colsample_bynode=1.0,
    reg_alpha=0.0,
    reg_lambda=1.0,
    gamma=0,
    min_child_weight=1,
    # scale_pos_weight=1,
    eval_metric='mlogloss',
    early_stopping_rounds=50,
    tree_method='hist',
    n_jobs=-1,
    random_state=2390
)

xgb.fit(x_train, y_train, eval_set=[(x_test, y_test)], verbose=False)

print("Best iteration:", xgb.best_iteration)
print("Test accuracy:",  xgb.score(x_test, y_test))
# Out:
# Best iteration: 116
# Test accuracy: 0.9736842105263158
