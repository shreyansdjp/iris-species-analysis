# %%
import pandas as pd

# %%
df = pd.read_csv("./iris/processed.csv")
df.rename(columns={"Species": "species"}, inplace=True)
df
# Out:
#       id  sepal_length  sepal_width  petal_length  petal_width  species
# 0      1           5.1          3.5           1.4          0.2        0
# 1      2           4.9          3.0           1.4          0.2        0
# 2      3           4.7          3.2           1.3          0.2        0
# 3      4           4.6          3.1           1.5          0.2        0
# 4      5           5.0          3.6           1.4          0.2        0
# ..   ...           ...          ...           ...          ...      ...
# 145  146           6.7          3.0           5.2          2.3        2
# 146  147           6.3          2.5           5.0          1.9        2
# 147  148           6.5          3.0           5.2          2.0        2
# 148  149           6.2          3.4           5.4          2.3        2
# 149  150           5.9          3.0           5.1          1.8        2
#
# [150 rows x 6 columns]

# %%
from sklearn.ensemble import GradientBoostingClassifier
from sklearn.model_selection import train_test_split
from sklearn.metrics import classification_report

# %%
x = df.loc[:, df.columns != "species"]
y = df["species"]
x_train, x_test, y_train, y_test = train_test_split(x, y, stratify=y, random_state=3029)
# Out:
#       id  sepal_length  sepal_width  petal_length  petal_width
# 0      1           5.1          3.5           1.4          0.2
# 1      2           4.9          3.0           1.4          0.2
# 2      3           4.7          3.2           1.3          0.2
# 3      4           4.6          3.1           1.5          0.2
# 4      5           5.0          3.6           1.4          0.2
# ..   ...           ...          ...           ...          ...
# 145  146           6.7          3.0           5.2          2.3
# 146  147           6.3          2.5           5.0          1.9
# 147  148           6.5          3.0           5.2          2.0
# 148  149           6.2          3.4           5.4          2.3
# 149  150           5.9          3.0           5.1          1.8
#
# [150 rows x 5 columns] 0      0
# 1      0
# 2      0
# 3      0
# 4      0
#       ..
# 145    2
# 146    2
# 147    2
# 148    2
# 149    2
# Name: species, Length: 150, dtype: int64

# %%
gb = GradientBoostingClassifier(
    n_estimators=200,
    learning_rate=0.1,
    max_depth=3,
    subsample=0.8,
    max_features=None,
    min_samples_split=2,
    min_samples_leaf=1,
    loss='log_loss',
    validation_fraction=0.1,
    n_iter_no_change=10,
    tol=1e-4,
    random_state=3029
)

gb.fit(x_train, y_train)
print("Training score:",    gb.train_score_[-1])
print("Test score:",        gb.score(x_test, y_test))
print("Actual trees built:", gb.n_estimators_)   # may be < 200 due to early stopping

# Staged prediction (performance after each tree)
staged = list(gb.staged_predict_proba(x_test))
# print(staged)

y_pred = gb.predict(x_test)

print(classification_report(y_test, y_pred))
# Out:
# Training score: 4.936622509513766e-05
# Test score: 1.0
# Actual trees built: 76
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00        12
#            1       1.00      1.00      1.00        13
#            2       1.00      1.00      1.00        13
#
#     accuracy                           1.00        38
#    macro avg       1.00      1.00      1.00        38
# weighted avg       1.00      1.00      1.00        38
